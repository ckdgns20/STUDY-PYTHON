# %%
#1
""" 방법 1
dict1 = dict(zip(['name','age'],[int(x) if x.isdigit() else x for x in input().split()]))

print(dict1)
"""
key1 = ["name","age"]
value1 = list(input().split())

dict1 = {key1[0]:value1[0],key1[1]:int(value1[1])}

print(dict1)
# Out:
# {'name': 'Minji', 'age': 24}

# %%
#2
dict2 = {'name':'Kim','score':85}

print(f"점수: {dict2["score"]}") # dict2.get("score") 도 가능
# Out:
# 점수: 85

# %%
#3
dict3 = {'name':'Kim','score':85}

dict3["score"] = 90

print(dict3)
# Out:
# {'name': 'Kim', 'score': 90}

# %%
#4
dict4 = {'name':'Kim','score':85}
dict4["major"] = "AI"

print(dict4)
# Out:
# {'name': 'Kim', 'score': 85, 'major': 'AI'}

# %%
#5
dict5 = {'name':'Minji','age':24}
rm_val = dict5.pop("age")

print(f"삭제값: {rm_val}")
print(f"남은 정보: {dict5}")
# Out:
# 삭제값: 24
# 남은 정보: {'name': 'Minji'}

# %%
#6
dict6 = {'name':'Minji','age':24}
print(dict6.get("height", 0))
# Out:
# 0

# %%
#7
dict7 = {'name':'Kim','score':85}

if "score" in dict7 :
    print("존재함")
else:
    print("없음")
# Out:
# 존재함

# %%
#8
temperature, vibration, pressure = map(float,(input().split()))

dict8 = {'temperature': temperature, 'vibration':vibration, 'pressure':pressure}
print(dict8)
# Out:
# {'temperature': 35.2, 'vibration': 0.18, 'pressure': 101.3}

# %%
#9
dict8["vibration"] = float(input())

print(dict8)
# Out:
# {'temperature': 35.2, 'vibration': 0.25, 'pressure': 101.3}

# %%
#10
for key in dict8.keys():
    print(key, end=" ")
# Out:
# temperature vibration pressure

# %%
#11
for value in dict8.values():
    print(value, end=" ")
# Out:
# 35.2 0.25 101.3

# %%
#12
for key, value in dict8.items(): # enumerate는 값은 빼고 key만 가져옴
    print(f"{key}={value}")
# Out:
# temperature=35.2
# vibration=0.25
# pressure=101.3

# %%
#13
setting_dict = {'fps':60,'stride':16,'window':64}
find_key = input()
print(setting_dict.get(find_key, "없음"))
# Out:
# 없음

# %%
#14
dict14 = {}
keys = ('normal', 'low', 'high', 'fault')

for key in keys :
    value = int(input())
    dict14[key] = value

print(dict14)
# Out:
# {'normal': 0, 'low': 1, 'high': 2, 'fault': 3}

# %%
#15
setting_dict = {'fps':60,'stride':16,'window':64}
setting_dict['stride'] = 8
setting_dict['batch'] = 32
del setting_dict['fps']

print(setting_dict)
# Out:
# {'stride': 8, 'window': 64, 'batch': 32}
