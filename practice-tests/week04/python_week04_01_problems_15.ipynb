# %%
#1

def hello():
    print("Hello, Python!")
    
    
hello()
# Out:
# Hello, Python!

# %%
#2
def show_profile():
    print("이름: Python")
    print("주제: Function")
    
show_profile()
# Out:
# 이름: Python
# 주제: Function

# %%
#3
def separator():
    print("----------")
    
separator()
separator()
# Out:
# ----------
# ----------

# %%
#4
def start_experiment():
    print("실험을 시작합니다.")

start_experiment()
# Out:
# 실험을 시작합니다.

# %%
#5
def step1():
    print("데이터 수집")
def step2():
    print("전처리")
def step3():
    print("분석")

step1()
step2()
step3()
# Out:
# 데이터 수집
# 전처리
# 분석

# %%
#6
step3()
step1()
step2()
# Out:
# 분석
# 데이터 수집
# 전처리

# %%
#7
def ping():
    for i in range(5):
        print("PING")
        
ping()
# Out:
# PING
# PING
# PING
# PING
# PING

# %%
#8
def line_experiment(name):
    print("==========")
    for id in name:
        print(f"실험 {id}")
        print("==========")
name_list = ["A","B"]
line_experiment(name_list)
# Out:
# ...
# 실험 A
# ...
# 실험 B
# ...

# %%
#9
def show_menu():
    print("1.  데이터 확인")
    print("2.  모델 실행")
    print("3.  종료")
    
show_menu()
# Out:
# 1.  데이터 확인
# 2.  모델 실행
# 3.  종료

# %%
#10
def camera_ready():
    print("카메라 연결 확인")
    print("스트림 설정")
    print("촬영 준비 완료")
    
camera_ready()
# Out:
# 카메라 연결 확인
# 스트림 설정
# 촬영 준비 완료

# %%
#11
def show_count():
    count = 3
    print(f"count: {count}")
    
show_count()
# Out:
# count: 3

# %%
#12
def message():
    print("첫 번째 함수")
message()
    
def message():
    print("두 번째 함수")
    
message()
# Out:
# 첫 번째 함수
# 두 번째 함수

# %%
#13
name = input()

def greet(name):
    print(f"안녕하세요, {name}님")
    
greet(name)
# Out:
# 안녕하세요, 창훈님

# %%
#14

def process_frame(frame_no):
        print(f"프레임 {frame_no} 처리 중")
for i in range(3):        
    process_frame(int(input()))
# Out:
# 프레임 0 처리 중
# 프레임 10 처리 중
# 프레임 20 처리 중

# %%
#15
def show_result(name, score):
    print(f"model-{name}: {score:.1f}")

for i in range(3):
    name = input("모델 이름을 입력하세요:")
    score = float(input("모델 성능을 입력하세요:"))
    show_result(name,score)
# Out:
# model-A: 95.2
# model-B: 97.1
# model-C: 93.8
